# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
times = np.linspace(0,4568e6*365.25*24*3600,1000)

# %%
T = np.linspace(6000,3000,1000)
C = 1e-10
T_0 = 10000
Teq = C*np.exp(-T/T_0)
dTeq = -C/T_0*np.exp(T/T_0)

plt.plot(T,dTeq*(1e9*365.25*24*3600))
